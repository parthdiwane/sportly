# %%
import pandas as pd 

df = pd.read_csv('/Users/parth/coding/python/sportly/stats/tennis_atp/singles/atp_matches_net.csv')
df
# Out:
#         Unnamed: 0.1  Unnamed: 0                  tourney_name surface  \
# 0                  0           0                        Dublin   Grass
# 1                  1           1                        Dublin   Grass
# 2                  2           2                        Dublin   Grass
# 3                  3           3                        Dublin   Grass
# 4                  4           4                        Dublin   Grass
# ...              ...         ...                           ...     ...
# 194991        194991      194991  Davis Cup WG2 PO: URU vs MDA    Clay
# 194992        194992      194992  Davis Cup WG2 PO: VIE vs RSA    Hard
# 194993        194993      194993  Davis Cup WG2 PO: VIE vs RSA    Hard
# 194994        194994      194994  Davis Cup WG2 PO: VIE vs RSA    Hard
# 194995        194995      194995  Davis Cup WG2 PO: VIE vs RSA    Hard
#
#         draw_size tourney_level  winner_seed winner_entry  \
# 0            32.0             A          NaN          NaN
# 1            32.0             A          NaN          NaN
# 2            32.0             A          NaN          NaN
# 3            32.0             A          NaN          NaN
# 4            32.0             A          NaN          NaN
# ...           ...           ...          ...          ...
# 194991        4.0             D          NaN          NaN
# 194992        4.0             D          NaN          NaN
# 194993        4.0             D          NaN          NaN
# 194994        4.0             D          NaN          NaN
# 194995        4.0             D          NaN          NaN
#
#                       winner_name winner_hand  ...  l_1stIn l_1stWon  \
# 0                      Doug Smith           U  ...      NaN      NaN
# 1                 Louis Pretorius           R  ...      NaN      NaN
# 2                    Cecil Pedlow           U  ...      NaN      NaN
# 3                       Tom Okker           R  ...      NaN      NaN
# 4                 Armistead Neely           R  ...      NaN      NaN
# ...                           ...         ...  ...      ...      ...
# 194991  Joaquin  Aguilar Cardozo            U  ...     30.0     17.0
# 194992               Nam Hoang Ly           R  ...     41.0     25.0
# 194993               Kris Van Wyk           R  ...     51.0     25.0
# 194994               Nam Hoang Ly           R  ...     51.0     32.0
# 194995             Philip Henning           R  ...     53.0     25.0
#
#         l_2ndWon  l_SvGms l_bpSaved l_bpFaced winner_rank  winner_rank_points  \
# 0            NaN      NaN       NaN       NaN         NaN                 NaN
# 1            NaN      NaN       NaN       NaN         NaN                 NaN
# 2            NaN      NaN       NaN       NaN         NaN                 NaN
# 3            NaN      NaN       NaN       NaN         NaN                 NaN
# 4            NaN      NaN       NaN       NaN         NaN                 NaN
# ...          ...      ...       ...       ...         ...                 ...
# 194991       7.0      6.0       8.0      14.0      1109.0                 8.0
# 194992       6.0      9.0       1.0       4.0       554.0                67.0
# 194993       7.0     11.0       5.0      12.0       416.0               109.0
# 194994      17.0     14.0       5.0       9.0       554.0                67.0
# 194995       8.0      8.0       9.0      14.0       748.0                32.0
#
#        loser_rank  loser_rank_points
# 0             NaN                NaN
# 1             NaN                NaN
# 2             NaN                NaN
# 3             NaN                NaN
# 4             NaN                NaN
# ...           ...                ...
# 194991      740.0               34.0
# 194992      748.0               32.0
# 194993        NaN                NaN
# 194994      416.0              109.0
# 194995        NaN                NaN
#
# [194996 rows x 46 columns]

# %%
df = df.drop(['winner_name','loser_name'],axis='columns')
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 tourney_name surface  draw_size tourney_level  \
# 0             0           0       Dublin   Grass       32.0             A
# 1             1           1       Dublin   Grass       32.0             A
# 2             2           2       Dublin   Grass       32.0             A
# 3             3           3       Dublin   Grass       32.0             A
# 4             4           4       Dublin   Grass       32.0             A
#
#    winner_seed winner_entry winner_hand  winner_ht  ... l_1stIn  l_1stWon  \
# 0          NaN          NaN           U        NaN  ...     NaN       NaN
# 1          NaN          NaN           R        NaN  ...     NaN       NaN
# 2          NaN          NaN           U        NaN  ...     NaN       NaN
# 3          NaN          NaN           R      178.0  ...     NaN       NaN
# 4          NaN          NaN           R        NaN  ...     NaN       NaN
#
#    l_2ndWon l_SvGms l_bpSaved  l_bpFaced winner_rank  winner_rank_points  \
# 0       NaN     NaN       NaN        NaN         NaN                 NaN
# 1       NaN     NaN       NaN        NaN         NaN                 NaN
# 2       NaN     NaN       NaN        NaN         NaN                 NaN
# 3       NaN     NaN       NaN        NaN         NaN                 NaN
# 4       NaN     NaN       NaN        NaN         NaN                 NaN
#
#   loser_rank  loser_rank_points
# 0        NaN                NaN
# 1        NaN                NaN
# 2        NaN                NaN
# 3        NaN                NaN
# 4        NaN                NaN
#
# [5 rows x 44 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
str_vals = ['tourney_name', 'surface','tourney_level','winner_hand','winner_ioc','loser_hand','loser_ioc','round']
label_encoder_variables = []
for variable_name in str_vals:
    var_name = "nlabel_" + variable_name
    globals()[var_name] = LabelEncoder()
    label_encoder_variables.append(globals()[var_name])

# %%
for i in range(len(str_vals)):
    df[str_vals[i] + "_n"] = label_encoder_variables[i].fit_transform(df[str_vals[i]])

# %%
for val in str_vals:
    df = df.drop([val],axis='columns')
df
# Out:
#         Unnamed: 0.1  Unnamed: 0  draw_size  winner_seed winner_entry  \
# 0                  0           0       32.0          NaN          NaN
# 1                  1           1       32.0          NaN          NaN
# 2                  2           2       32.0          NaN          NaN
# 3                  3           3       32.0          NaN          NaN
# 4                  4           4       32.0          NaN          NaN
# ...              ...         ...        ...          ...          ...
# 194991        194991      194991        4.0          NaN          NaN
# 194992        194992      194992        4.0          NaN          NaN
# 194993        194993      194993        4.0          NaN          NaN
# 194994        194994      194994        4.0          NaN          NaN
# 194995        194995      194995        4.0          NaN          NaN
#
#         winner_ht  winner_age  loser_seed loser_entry  loser_ht  ...  \
# 0             NaN         NaN         NaN         NaN       NaN  ...
# 1             NaN         NaN         NaN         NaN       NaN  ...
# 2             NaN         NaN         NaN         NaN       NaN  ...
# 3           178.0        24.3         NaN         NaN       NaN  ...
# 4             NaN        21.3         NaN         NaN       NaN  ...
# ...           ...         ...         ...         ...       ...  ...
# 194991        NaN        18.8         NaN         NaN     188.0  ...
# 194992      175.0        26.9         NaN         NaN       NaN  ...
# 194993      185.0        27.3         NaN         NaN     183.0  ...
# 194994      175.0        26.9         NaN         NaN     185.0  ...
# 194995        NaN        23.2         NaN         NaN     183.0  ...
#
#         loser_rank loser_rank_points  tourney_name_n  surface_n  \
# 0              NaN               NaN            3780          2
# 1              NaN               NaN            3780          2
# 2              NaN               NaN            3780          2
# 3              NaN               NaN            3780          2
# 4              NaN               NaN            3780          2
# ...            ...               ...             ...        ...
# 194991       740.0              34.0            3721          1
# 194992       748.0              32.0            3722          3
# 194993         NaN               NaN            3722          3
# 194994       416.0             109.0            3722          3
# 194995         NaN               NaN            3722          3
#
#         tourney_level_n  winner_hand_n  winner_ioc_n  loser_hand_n  \
# 0                     0              3             5             3
# 1                     0              2            98             3
# 2                     0              3            54             3
# 3                     0              2            81             3
# 4                     0              2           124             3
# ...                 ...            ...           ...           ...
# 194991                1              3           123             2
# 194992                1              2           127             2
# 194993                1              2            98             2
# 194994                1              2           127             2
# 194995                1              2            98             2
#
#         loser_ioc_n  round_n
# 0                61        6
# 1                61        6
# 2                61        6
# 3               145        6
# 4                61        6
# ...             ...      ...
# 194991           82        8
# 194992          109        8
# 194993          141        8
# 194994          109        8
# 194995          141        8
#
# [194996 rows x 44 columns]
